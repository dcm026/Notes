# %%
'''Matplotlib & Seaborn NOTES'''

# NOTE: jupyter shortcut: shift + tab to show tooltips for a given function

# %%
'''Notes from online course: Python for Data Science and Machine Learning Bootcamp by Jose Portilla'''
# Out:
# 'Notes from online course: Python for Data Science and Machine Learning Bootcamp by Jose Portilla'

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from numpy.random import randn, randint, rand
np.random.seed(101)
# %matplotlib inline

# %%
x = np.linspace(0,5,11)
y = x ** 2
plt.plot(x, y) # functional method
plt.xlabel('X label')
plt.ylabel('Y label')
plt.title('Title')
# plt.show() if not in jupyter notebook
# Out:
# Text(0.5, 1.0, 'Title')

# %%
plt.subplot(1, 2, 1) # num_rows, num_cols, plot_num refering to
plt.plot(x, y, 'r')
plt.subplot(1, 2, 2)
plt.plot(y, x, 'b')

# %%
 # OO approach
fig = plt.figure()
axes = fig.add_axes([.1, .1, .8, .8]) # % from left , % from bot, width % of canvis size, height % of canvis size
axes.plot(x, y)
axes.set_xlabel('X label')
# Out:
# Text(0.5, 0, 'X label')

# %%
fig = plt.figure()
axes1 = fig.add_axes([.1, .1, .8, .8])
axes2 = fig.add_axes([.2, .5, .4, .3])
axes1.plot(x, y)
axes2.plot(y, x)
axes1.set_title('Bigger Plot')
axes2.set_title('Smaller Plot')
# Out:
# Text(0.5, 1.0, 'Smaller Plot')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)
for ax in axes:
    ax.plot(x, y)
axes[0].set_title('Plot 0')
plt.tight_layout()
# Out:
# Text(0.5, 1, 'Plot 0')

# %%
fig = plt.figure(figsize=(3,2)) # 3 inches wide by 2 inches tall
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)

# %%
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(3,4))
axes[0].plot(x, y)
axes[1].plot(y, x)
plt.tight_layout()

# %%
fig.savefig('my_plot.png', dpi=200) # save picture of plot

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, x ** 2, label='x squared')
ax.plot(x, x ** 3, label='x cubed')
ax.legend() # loc.legend(loc=0) # 0: best location, 1: upper right, 2: upper left, 3: low lt, 4: lw rt, 10: center
# loc.legend(loc=(.1, .1))

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='green', lw=2, alpha=.5, linestyle='--', marker='o', markersize=10) # or can use RGB hex code: color='#FF8C00'
# linewidth: lw=1 is default, alpha (transparency from 0 to 1)

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y, color='green')
ax.set_xlim([0,1]) # define boundary for x axis
ax.set_ylim([0,5])
# Out:
# (0, 5)

# %%
'''SEABORN'''
# Out:
# 'SEABORN'

# %%
import seaborn as sns
# %matplotlib inline

# %%
'''Distribution Plots'''

tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# UNIVARIATE
sns.distplot(tips['total_bill'], kde=False, bins=30)

# %%
# BIVARIATE
sns.jointplot(x='total_bill', y='tip', data=tips)

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='reg')

# %%
sns.jointplot(x='total_bill', y='tip', data=tips, kind='kde')

# %%
# BIVARIATE -- plot every pair of attributes
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue='sex')

# %%
# kde: kernal density estimation

# %%
'''Categorical Plots'''
# Out:
# 'Categorical Plots'

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.barplot(x='sex', y='total_bill', data=tips)

# %%
sns.barplot(x='sex', y='total_bill', data=tips, estimator=np.std)

# %%
sns.countplot(x='sex', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips)

# %%
sns.boxplot(x='day', y='total_bill', data=tips, hue='smoker')

# %%
sns.violinplot(x='day', y='total_bill', data=tips)

# %%
sns.violinplot(x='day', y='total_bill', data=tips, hue='sex', split=True)

# %%
sns.catplot(x='day', y='total_bill', data=tips, kind='bar')

# %%
'''Matrix Plots'''
# Out:
# 'Matrix Plots'

# %%
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
cor = tips.corr() # correlation
cor
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(cor, annot=True, cmap='coolwarm')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
fp = flights.pivot_table(index='month', columns='year', values='passengers')
fp
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
sns.heatmap(fp, cmap='coolwarm')

# %%
'''Grids'''
# Out:
# 'Grids'

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.pairplot(iris)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# UNIVARIATE (total_bill) seperated by by time and smoker category
g = sns.FacetGrid(data=tips, col='time', row='smoker')
g.map(sns.distplot, 'total_bill')

# %%
# BIVARIATE (total_bill vs tip) seperated by by time and smoker category
g = sns.FacetGrid(data=tips, col='time', row='smoker')
g.map(plt.scatter, 'total_bill', 'tip')

# %%
'''Regression Plots'''
# Out:
# 'Regression Plots'

# %%
sns.lmplot(x='total_bill', y='tip', data=tips)

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', markers=['o', 'v'])

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex')

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, col='sex', hue='time')

# %%
'''Styles & Color'''
# Out:
# 'Styles & Color'

# %%
plt.figure(figsize=(8,6)) # width by height
sns.set_style('whitegrid')
sns.countplot(x='sex', data=tips)
